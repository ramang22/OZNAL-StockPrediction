# %%
import yfinance as yf
import numpy as np
import pandas as pd
import requests
import io
import yfinance as yf
import datetime
import time

# %%
stock = yf.download("BTC-USD",'2016-01-01','2018-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
url="http://ftp.nasdaqtrader.com/dynamic/SymDir/nasdaqlisted.txt"
s = requests.get(url).content
#companies = pd.read_csv(io.StringIO(s.decode('utf-8')))
read_file = pd.read_csv(url,delimiter="|")

# %%
read_file[read_file['Symbol'] == 'BTC']
# Out:
# Empty DataFrame
# Columns: [Symbol, Security Name, Market Category, Test Issue, Financial Status, Round Lot Size, ETF, NextShares]
# Index: []
